# %%
import pandas as pd
import numpy as np

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score
from sklearn.linear_model import LogisticRegression

# %% [markdown]
# Flow of model:
#
#
# 1.   importing dataset
# 2.   Data preparation
# 3.   Train_test_split
# 4.   Risk_model building
# 5.   Model performance
# 6.   Testing model
# 7.   Storing model in xlsx format

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
dataset=pd.read_excel("/content/drive/My Drive/a_Dataset_CreditScoring.xlsx")

# %%
dataset.shape
# Out:
# (3000, 30)

# %%
dataset.isna().sum()
# Out:
# TARGET               0
# ID                   0
# DerogCnt             0
# CollectCnt           0
# BanruptcyInd         0
# InqCnt06             0
# InqTimeLast        188
# InqFinanceCnt24      0
# TLTimeFirst          0
# TLTimeLast           0
# TLCnt03              0
# TLCnt12              0
# TLCnt24              0
# TLCnt                3
# TLSum               40
# TLMaxSum            40
# TLSatCnt             4
# TLDel60Cnt           0
# TLBadCnt24           0
# TL75UtilCnt         99
# TL50UtilCnt         99
# TLBalHCPct          41
# TLSatPct             4
# TLDel3060Cnt24       0
# TLDel90Cnt24         0
# TLDel60CntAll        0
# TLOpenPct            3
# TLBadDerogCnt        0
# TLDel60Cnt24         0
# TLOpen24Pct          3
# dtype: int64

# %%
dataset=dataset.fillna(dataset.mean())

# %%
dataset
# Out:
#       TARGET      ID  DerogCnt  CollectCnt  BanruptcyInd  InqCnt06  \
# 0          1     582         3           3             0         4
# 1          1     662        15           9             0         3
# 2          1     805         0           0             0         1
# 3          1    1175         8           5             0         6
# 4          1    1373         3           1             0         9
# ...      ...     ...       ...         ...           ...       ...
# 2995       0  126441         0           0             0         2
# 2996       0  126448         0           0             0         0
# 2997       0  126465         1           1             0         8
# 2998       0  126487         4           4             0         2
# 2999       0  126503         2           1             1         0
#
#       InqTimeLast  InqFinanceCnt24  TLTimeFirst  TLTimeLast  ...  TL50UtilCnt  \
# 0        0.000000                5          117          27  ...          3.0
# 1        1.000000                3           14          14  ...          1.0
# 2        5.000000                1          354           7  ...          5.0
# 3        1.000000               10           16           4  ...          3.0
# 4        0.000000                8          130          52  ...          1.0
# ...           ...              ...          ...         ...  ...          ...
# 2995     0.000000                2          199          10  ...          9.0
# 2996     3.108108                0          270           3  ...          5.0
# 2997     0.000000                5          234           4  ...          9.0
# 2998     3.000000                1          257           3  ...          3.0
# 2999    18.000000                0          254         119  ...          1.0
#
#       TLBalHCPct  TLSatPct  TLDel3060Cnt24  TLDel90Cnt24  TLDel60CntAll  \
# 0         0.9179    0.2083               2             3              7
# 1         0.8000    0.0000               0             0              0
# 2         0.3552    0.6538               0             1              1
# 3         0.9127    0.2500               1             1              1
# 4         1.2511    0.0000               0             1              4
# ...          ...       ...             ...           ...            ...
# 2995      0.7853    0.6923               0             0              0
# 2996      0.5766    0.9286               0             0              0
# 2997      0.8722    0.6071               0             0              0
# 2998      1.0391    0.6000               0             1              2
# 2999      0.3239    0.1667               0             2              4
#
#       TLOpenPct  TLBadDerogCnt  TLDel60Cnt24  TLOpen24Pct
# 0        0.2083              4             4       0.0000
# 1        1.0000             12             0       1.0000
# 2        0.7308              1             1       0.5263
# 3        0.7500              7             1       1.3333
# 4        0.1429              3             1       0.0000
# ...         ...            ...           ...          ...
# 2995     0.6538              0             0       0.3529
# 2996     0.8571              0             0       0.4167
# 2997     0.4286              1             0       0.7500
# 2998     0.6000              4             1       1.0000
# 2999     0.5000              3             2       0.0000
#
# [3000 rows x 30 columns]

# %%
dataset['CollectCnt']
# Out:
# 0       3
# 1       9
# 2       0
# 3       5
# 4       1
#        ..
# 2995    0
# 2996    0
# 2997    1
# 2998    4
# 2999    1
# Name: CollectCnt, Length: 3000, dtype: int64

# %%
#model training (Train_Test_split)

# %%
y=dataset.iloc[:,0].values
X=dataset.iloc[:,1:28].values

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2,random_state=0)

# %%
sc=StandardScaler()
X_train=sc.fit_transform(X_train)
X_test=sc.transform(X_test)

# %%
classifier=LogisticRegression()
classifier.fit(X_train,y_train)
y_pred=classifier.predict(X_test)

# %%
print(confusion_matrix(y_test,y_pred))
# Out:
# [[482  16]
#  [ 84  18]]

# %%
print(accuracy_score(y_test,y_pred))
# Out:
# 0.8333333333333334

# %%
predictions=classifier.predict_proba(X_test)

predictions
# Out:
# array([[0.04056882, 0.95943118],
#        [0.93084336, 0.06915664],
#        [0.70141215, 0.29858785],
#        ...,
#        [0.9689144 , 0.0310856 ],
#        [0.48408942, 0.51591058],
#        [0.87566639, 0.12433361]])

# %%
df_prediction_prob = pd.DataFrame(predictions, columns = ['prob_0', 'prob_1'])
df_prediction_target = pd.DataFrame(classifier.predict(X_test), columns = ['predicted_TARGET'])
df_test_dataset = pd.DataFrame(y_test,columns= ['Actual Outcome'])

dfx=pd.concat([df_test_dataset, df_prediction_prob, df_prediction_target], axis=1)

dfx.to_csv("/content/drive/My Drive/c1_Model_Prediction.xlsx", sep=',', encoding='UTF-8')

dfx.head()
# Out:
#    Actual Outcome    prob_0    prob_1  predicted_TARGET
# 0               1  0.040569  0.959431                 1
# 1               0  0.930843  0.069157                 0
# 2               0  0.701412  0.298588                 0
# 3               0  0.921041  0.078959                 0
# 4               0  0.881096  0.118904                 0

# %%
dfx
# Out:
#      Actual Outcome    prob_0    prob_1  predicted_TARGET
# 0                 1  0.040569  0.959431                 1
# 1                 0  0.930843  0.069157                 0
# 2                 0  0.701412  0.298588                 0
# 3                 0  0.921041  0.078959                 0
# 4                 0  0.881096  0.118904                 0
# ..              ...       ...       ...               ...
# 595               0  0.980878  0.019122                 0
# 596               0  0.968780  0.031220                 0
# 597               0  0.968914  0.031086                 0
# 598               1  0.484089  0.515911                 1
# 599               0  0.875666  0.124334                 0
#
# [600 rows x 4 columns]
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# dfx['Actual Outcome'].plot(kind='hist', bins=20, title='Actual Outcome')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# dfx['prob_0'].plot(kind='hist', bins=20, title='prob_0')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# dfx['prob_1'].plot(kind='hist', bins=20, title='prob_1')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# dfx['predicted_TARGET'].plot(kind='hist', bins=20, title='predicted_TARGET')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# dfx.plot(kind='scatter', x='Actual Outcome', y='prob_0', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# dfx.plot(kind='scatter', x='prob_0', y='prob_1', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# dfx.plot(kind='scatter', x='prob_1', y='predicted_TARGET', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# dfx['Actual Outcome'].plot(kind='line', figsize=(8, 4), title='Actual Outcome')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# dfx['prob_0'].plot(kind='line', figsize=(8, 4), title='prob_0')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# dfx['prob_1'].plot(kind='line', figsize=(8, 4), title='prob_1')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# dfx['predicted_TARGET'].plot(kind='line', figsize=(8, 4), title='predicted_TARGET')
# plt.gca().spines[['top', 'right']].set_visible(False)

# %%
dfx.shape
# Out:
# (600, 4)

# %%
dfx.isna().sum()
# Out:
# Actual Outcome      0
# prob_0              0
# prob_1              0
# predicted_TARGET    0
# dtype: int64
